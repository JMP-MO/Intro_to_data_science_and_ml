# %% [markdown]
# <a href="https://colab.research.google.com/github/JMP-MO/Intro_to_data_science_and_ml/blob/main/Intro_to_DS_and_ML_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Data Science & Machine Learning 1

# %% [markdown]
# ### Learning outcomes:
# 1. Understand what data science is and some of the key areas such as machine learning.
# 2. Able to get and load tabular data.
# 3. Use common techniques to explore tabular data.

# %% [markdown]
# ### Google Colab / Jupyter Notebook Tips
# > * Shift + Return = run cell.
# > * Jupyter & Colab notebooks are not dynamic - you need to rerun cells if you change something.
# > * Some cells are for code, some are for markdown text - they behave differently.
# > * Start a code cell with `!` to run a terminal command like `! pip install package_name`
# > * On Google Colab after a while of inactivity, closing the window or crashing the runtime (usually by running out of RAM) the runtime will reset. If you are on a free account this will delete any files you have downloaded / created in the Google Colab 'files' space.
# > * With Google Colab - you can switch to a GPU runtime with an NVIDIA GPU. However, on the free account this is time limited and not guarenteed. Therefore use the CPU runtime for most of your work until you need a GPU for instance for GPU (NVIDIA cuda) enabled machine learning training - we will cover this later.

# %% [markdown]
# ### What is Data Science, AI, Machine Learning, Neural Networks and Deep Learning?
#
# Data Science is a wide area of computer science that includes AI, ML, Deep Learning, Large Language Models and Generative AI.

# %% [markdown]
# ![B0C61421-C113-4ADB-88B0-D4AFED583751.JPG](data:image/jpeg;base64,...)
#
# Adapted from: https://www.researchgate.net/figure/Relationship-between-artificial-intelligence-machine-learning-neural-network-and-deep_fig3_354124420

# %% [markdown]
# ### What is Machine Learning?
#
# Machine learning is **predicting a number, with some other numbers** using an **algorithm that learns from data**. For instance:
# > 1. If we trained a model on historic weather data and know the temperature now, could we predict it in 6 hours? (Regression)
# > 2. If we represent words with numbers and trained a model on historic text and text on the internet, if given a sequence of words (numbers), can we predict the next words (numbers).
# > 3. If we trained a model by giving it millions of labelled images, could we predict the label associated with the key object in the image. (Supervised learning) (Classification)
# > 4. If given unlablled data such as medical records, could we train a model to recognise patterns that may indicate the patient has a high chance of developing a particular disease. (Unsupervised learning) (Clustering)
#
#
# There are many more types of machine learning but these are the main categories you probably want to start with:
# * Supervised and Unsupervised learning
# * Regression and Classification
#
#
# ![image.png](data:image/png;base64,...)
#
# https://www.researchgate.net/figure/Supervised-and-unsupervised-machine-learning-a-Schematic-representation-of-an_fig3_351953193
#
# ![image.png](data:image/png;base64,...)
#
# https://spotintelligence.com/2023/05/02/regression-vs-classification/

# %% [markdown]
# * **Regression** - trying to represent the general trend of the data.
# * **Classification** - separating the data into groups.

# %% [markdown]
# ### What is the Machine Learning process?

# %% [markdown]
# ![Screenshot 2026-02-09 144114.png](data:image/png;base64,...)
#
# https://www.researchgate.net/figure/Fig-2-Machine-learning-process-diagram_fig2_373826952

# %% [markdown]
# ## Exploring tabular data
#
# Before we can start machine learning we need data. The first step is getting and understanding our data. In this notebook we are going to explore a tabular dataset covering some basic functions and methods to load and explore our data.

# %% [markdown]
# ### Get data

# %% [markdown]
# Lets get some data by downloading this .csv file. If you find a .csv file on github click on the `raw` button to get the url for the raw file to download. We will use the `!` character to indicate this is a terminal command. Run the cell below to get your data.

# %%
! wget https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/pandas/tests/io/data/csv/tips.csv
# Out:
# --2026-02-02 16:56:50--  https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/pandas/tests/io/data/csv/tips.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7943 (7.8K) [text/plain]
# Saving to: ‘tips.csv’
#
# tips.csv            100%[===================>]   7.76K  --.-KB/s    in 0s
#
# 2026-02-02 16:56:50 (69.1 MB/s) - ‘tips.csv’ saved [7943/7943]

# %%
# TASK - In Google Colab the file will be downloaded to the `Files` folder. Check for a `tips.csv` file.

# %% [markdown]
# ### Imports and environments
#
# You may have come across the `Pandas` python package before. This package enables us to explore 2-dimensional data. This is great for working with .csv type files. This type of 2d data is called **tabular**.
#
# We need to import the pandas library to explore this 2d data. Its common to give it the alias `pd`. Google Colab has a default environment with many packages like pandas installed. If working on your own machine, you will need to create a `virtual environment`, activate it and install the package using a package manager like `pip`, `uv` or `conda`. Package management are very important skills to develop!

# %%
import pandas as pd

# %% [markdown]
# ### Reading a file

# %% [markdown]
# Now we can read the `tips.csv` file we downloaded into memory.

# %%
tips_data = pd.read_csv("add_filename_here.csv")

# %% [markdown]
# ### Exploring 2d data

# %% [markdown]
# Lets explore our data by looking at the first 5 results using the `.head(x)` method. <br>
# >You should be able to see that this is some data about restaurant customers and the tips they leave. I wonder if we could predict the tip amount using the other information? Or perhaps predict if they are Male / Female based on the `total_bill` and `tip` amounts. What other things might be useful to try and predict?

# %%
tips_data.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Try the .sample(5) method in this cell - what does this do?

# %%
# Try .tail(5) method in this cell - what does this do?

# %% [markdown]
# Pandas has lots of useful functions to help you explore data. Explore some of the following methods on the `tips_data`.

# %%
# .info() is useful - what is the different between float64, int64 and object? Why object?

# %%
# .describe() - what does this present? How could this information help you understand your data?

# %%
# .shape - don't add parentheses. - What does this tell you? (Shape will be super helpful for ML work)

# %%
# .columns - don't add parentheses. - What info does this give you? This will also be useful later.

# %% [markdown]
# There are lots more pandas methods and useful techniques to select, filter, group, index and transform your data. If you use pandas regularly you can easily pick these methods up. However as we will see later, pandas soon loses its power when dealing with more complex data.

# %% [markdown]
# ### Numpy
#
# Next we will look at some key data engineering techniques we need for machine learning. We will need a library called `numpy` that is used for a lot or numerical representations and can speed up tasks significantly.

# %%
import numpy as np

# %%
python_array = [1,2,3,4]
print("Python array", type(python_array))

numpy_array = np.array([1,2,3,4])
print("Numpy array", numpy_array)

# TASK - create your own numpy array using the np.array() method by manually coding an array in the parenthesis.
# TASK - print the datatype to check.




# TASK - create a numpy array using the np.array() method by assigning a python array variable within the brackets - useful to convert python to numpy.
# TASK - print the datatype to check
# Out:
# Python array <class 'list'>
# Numpy array [1 2 3 4]

# %% [markdown]
# Lets run a little experiment to show the speed difference using numpy over a python list.
# >Do you know WHY numpy can execute a repetitive function such as this so much quicker?

# %%
import time

size = 10_000_000
py_list = [x for x in range(size)]  # Create a python list - using 'list comprehension' loop for extra speed 🏃
np_array = np.array(py_list)        # Create a numpy array from the py_list.

# --- Python list ---
start = time.time()
total_list = sum([x**2 for x in py_list])
end = time.time()
print(f"Python list time: {end - start:.5f} seconds")

# --- NumPy array ---
start = time.time()
total_numpy = np.sum(np_array**2)
end = time.time()
print(f"NumPy array time: {end - start:.5f} seconds")
# Out:
# Python list time: 1.24367 seconds
# NumPy array time: 0.03217 seconds

# %% [markdown]
# The next notebook will focus on some specific data engineering techniques required for machine learning.
